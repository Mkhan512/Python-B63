# %% [markdown]
# <a href="https://colab.research.google.com/github/Mkhan512/Python-B63/blob/main/API_key.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q "google-generativeai>=0.7.2" # Install the Python SDK

# %%
import google.generativeai as genai

# %%
genai.configure(api_key="AIzaSyB6ZL1qVUFFQnA2kxgm9bhde6owqV_cujs")

# %%
genai.configure(api_key="AIzaSyB6ZL1qVUFFQnA2kxgm9bhde6owqV_cujs")
model_1 = genai.GenerativeModel("gemini-1.5-flash")
response = model_1.generate_content(input("type any thing:")) #"Explain how chatbot works")
print(response.text)
# Out:
# type any thing: Why LLM
# LLMs, or Large Language Models, are impactful because of their ability to understand and generate human-like text. This capability opens up a wide range of applications and advantages. Here's a breakdown of why LLMs are important:
#
# **Key Advantages and Applications:**
#
# * **Natural Language Understanding (NLU):** LLMs excel at understanding the nuances of human language, including context, intent, and sentiment.  This allows them to perform tasks like:
#     * **Sentiment analysis:** Determining the emotional tone of text.
#     * **Topic extraction:** Identifying the main subjects discussed in a document.
#     * **Question answering:** Providing accurate and informative responses to questions.
#     * **Machine translation:** Converting text from one language to another.
#
# * **Natural Language Generation (NLG):** LLMs can generate coherent and contextually relevant text, leading to applications such as:
# ...
